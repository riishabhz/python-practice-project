# %%
from bs4 import BeautifulSoup # BeautifulSoup is in bs4 package 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
import csv
from selenium.webdriver.common.proxy import Proxy, ProxyType
import time 
import re
from selenium.common.exceptions import NoSuchElementException
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-d2aeff0f06e2> in <module>
#       8 import re
#       9 from selenium.common.exceptions import NoSuchElementException
# ---> 10 from textblob import textblob
#
# ImportError: cannot import name 'textblob' from 'textblob' (C:\ProgramData\Anaconda3\lib\site-packages\textblob\__init__.py)

# %%
pip install TextBlob
# Out:
# Requirement already satisfied: TextBlob in c:\programdata\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from TextBlob) (3.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->TextBlob) (1.12.0)
# Requirement already satisfied: singledispatch in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->TextBlob) (3.4.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
option = Options()

option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")

option.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 2 
})

# %%
driver=webdriver.Chrome(chrome_options=option,executable_path=r"chromedriver.exe")

url = 'https://www.instagram.com/p/B43gVRGgEpn/'
driver.get(url)

with open("instagramcomments.csv","w",encoding="utf8") as f1:
    f1.write("id,comment\n")


t=0
with open("instagramcomments.csv", "a", encoding="utf8") as csv_file:
    while True:
        #time.sleep(0.5)
        t += 1
        print(t)
        try:
            instagramidxpath=driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/div[2]/div[1]/ul/ul[{}]/div/li/div/div/div[2]/h3/a'.format(str(t)))
            href=instagramidxpath.get_attribute('href')
            print(href)
            comment=driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/div[2]/div[1]/ul/ul[{}]/div/li/div/div[1]/div[2]/span'.format(str(t)))
            comment=comment.text
            print(comment)
            data = href + ',' + comment + '\n' 
            csv_file.write(data)
            #time.sleep(0.2)
        except:
            break
        
        try:
            load_more_comment = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/div[2]/div[1]/ul/li/div/button/span')
            load_more_comment.click()
            time.sleep(0.7)
        except:
            pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use options instead of chrome_options
#   """Entry point for launching an IPython kernel.
# 1
# https://www.instagram.com/smarrig_vegansk_mat_/
# Stop using leather 😡😡😡😡😡😡
# 2
# https://www.instagram.com/whoisyessin/
# Please stop using leather 🙌
# 3
# https://www.instagram.com/priyadarshnee_das/
# Price.?
# 4
# https://www.instagram.com/chhavijain40/
# When will it be available in indian stores?
# 5
# https://www.instagram.com/daniele.pio.grieco/
# please stop selling leather
# 6
# https://www.instagram.com/mrdc1977/
# Good look 💜💜💜 !!!!!
# 7
# https://www.instagram.com/golden_globetrotter/
# Yesss!! Love this! 😍
# 8
# https://www.instagram.com/authentique_4/
# 🔥❤️
# 9
# https://www.instagram.com/chhavijain40/
# When will it be available in indian stores?
# 10
# https://www.instagram.com/abdullah.tunes/
# Can i have it??for freee some givemmr this
# 11
# https://www.instagram.com/katerina_thns/
# 😍😍😍😍😍
# 12
# https://www.instagram.com/falonne_mj/
# ❤️❤️❤️😍
# 13
# https://www.instagram.com/smarrig_vegansk_mat_/
# Stop using leather 😡😡😡😡😡😡
# 14
# https://www.instagram.com/whoisyessin/
# Please stop using leather 🙌
# 15
# https://www.instagram.com/priyadarshnee_das/
# Price.?
# 16
# https://www.instagram.com/eachdayisagift22/
# 😍
# 17
# https://www.instagram.com/gigiszmom/
# @spindabenzzz
# 18
# https://www.instagram.com/precotune/
# Levi’s level
# 19
# https://www.instagram.com/ootd_tarzim/
# 🌸🌸🌸🌸🌸🌸
# 20
# https://www.instagram.com/yellowfairy11111/
# Cool
# 21
# https://www.instagram.com/ayunten/
# 😍💙sherpa🔥
# 22
# https://www.instagram.com/iamarunmalhotra/
# ❤️
# 23
# https://www.instagram.com/yayarley/
# @_mattttam_ SHERPA
# 24
# https://www.instagram.com/mehwish.mughees/
# How to order
# 25
# https://www.instagram.com/jillianill_/
# STOP KILLING COWS FOR A PATCH OF LEATHER !!!!
# 26
# https://www.instagram.com/dz_trotters/
# ❤️❤️❤️❤️❤️
# 27
# https://www.instagram.com/iam_albertalsina/
# ❤😍
# 28
# https://www.instagram.com/morrisetmax/
# 💙💙💙
# 29
# https://www.instagram.com/bagoewanja/
# ❤️❤️
# 30
# https://www.instagram.com/inesanco/
# ❤️
# 31
# https://www.instagram.com/mehdiahed.official/
# Perfect bur it's rare in my country 😭.
# 32
# https://www.instagram.com/herman_isruyadi/
# 👍👍👍👍
# 33
# https://www.instagram.com/fusionmodels_ct/
# That jacket 🧥
# 34
# https://www.instagram.com/desiirerae/
# ❤️❤️🔥🔥❤️❤️
# 35
# https://www.instagram.com/zoltanyaster/
# 👍🏾
# 36
# https://www.instagram.com/emmalucytayler/
# Levi's copied my outfit again @rorytayler 💛
# 37
# https://www.instagram.com/fly_soul___/
# 🌿____🌷___🌷🌷🌷___🌷___🌷🌷🌷____🌿___🌷🌷🌷___🌷___🌷🌷🌷____🌿_____
# 38
# https://www.instagram.com/thebagystore/
# ❤💛
# 39
# https://www.instagram.com/unsolvedriddle00/
# Nice looking jacket👌👌👌
# 40
# https://www.instagram.com/shoplifego/
# 💜
# 41
# https://www.instagram.com/tuff4sho/
# Coloraid
# 42
# https://www.instagram.com/catalinarodriguez431/
# Hola los precios son mexicanos o euros
# 43
# https://www.instagram.com/lothevi/
# 😮
# 44
# https://www.instagram.com/offical_unseen/
# 😍
# 45
# https://www.instagram.com/alexandreleclair/
# 😍
# 46
# https://www.instagram.com/lucilaa10/
# Hola precio
# 47
# https://www.instagram.com/_maribat/
# 😍
# 48
# https://www.instagram.com/r.rahulchoudhary/
# Awesome brand
# 49
# https://www.instagram.com/jeff_khalifa_1/
# 💙💙💙
# 50
# https://www.instagram.com/insane.police.vids/
# I show the craziest 18+ police situations! Click on my main account in bi0 😲🤯
# 51
# https://www.instagram.com/elvandross/
# @katydm Sherpa!
# 52
# https://www.instagram.com/henryhallphotograph/
# 👍😎 @levis
# 53
# https://www.instagram.com/lauralilianvazquez/
# ❤️
# 54

# %%
analysis=
